# %% [markdown]
# # Case Study: Modelling: AutoML

# %% [markdown]
# ## 01 Project Description
#
# Lending Bank wants to attract term deposits to fund its lending business. In a term deposit, a client agrees to deposit funds and allow the bank to use them for a fixed length of time. In return, the bank will pay interest on the deposit.
#
# The bank’s sales manager wants to market the product to their existing clients. They have historical information from a previous marketing campaign that includes client demographics, prior call experience, market conditions and the interest rate offered.
#
# Using machine learning, help the bank predict which clients are likely to subscribe to a new term deposit. Explain how different features affect the decision.
#
# **Problem**
#
# Perform an analysis of the given data to determine how different features are related to credit card eligibility. Build a machine learning model that can predict the subs_deposit.

# %% [markdown]
# ## 02 Load Training and Test Data

# %%
import pandas as pd
data_filepath = '../data/raw/train.csv'
df_preview = pd.read_csv(data_filepath, nrows=10)
display(df_preview.head())
# Out:
#    client_id age_bracket           job   marital         education  \
# 0      41020       41-60  white-collar  divorced         bachelors
# 1      23720         60+         other  divorced         secondary
# 2      29378       41-60  white-collar   married         bachelors
# 3      36636       25-40    technician    single  senior_secondary
# 4      38229       18-24  white-collar    single         bachelors
#
#   has_housing_loan has_personal_loan  prev_call_duration  \
# 0              yes                no                 283
# 1               no               yes                 169
# 2               no                no                 552
# 3              yes               yes                 206
# 4               no                no                 341
#
#    days_since_last_call  num_contacts_prev     poutcome contact_date     cpi  \
# 0                     3                  1      success     07/09/18  92.379
# 1                     6                  2      success     05/07/18  94.215
# 2                   999                  0  nonexistent     01/08/18  93.444
# 3                   999                  0  nonexistent     02/11/18  93.200
# 4                   999                  0  nonexistent     04/04/18  93.075
#
#    subs_deposit
# 0             1
# 1             1
# 2             1
# 3             0
# 4             1

# %%
sample_type = {
    'client_id': 'str',
 'age_bracket': 'str',
 'job': 'str',
 'marital': 'str',
 'education': 'str',
 'has_housing_loan': 'str',
 'has_personal_loan': 'str',
 'prev_call_duration': 'int',  
 'days_since_last_call': 'int',  
 'num_contacts_prev':'int', 
 'poutcome': 'str',
 'contact_date': 'str',
 'cpi': 'float',
 'subs_deposit':'int', 
}
df_raw_train = pd.read_csv(
    data_filepath,
    index_col=['client_id'],
    parse_dates=['contact_date'],
    dtype=sample_type,
)
display(df_raw_train.head())
# Out:
#           age_bracket           job   marital         education  \
# client_id
# 41020           41-60  white-collar  divorced         bachelors
# 23720             60+         other  divorced         secondary
# 29378           41-60  white-collar   married         bachelors
# 36636           25-40    technician    single  senior_secondary
# 38229           18-24  white-collar    single         bachelors
#
#           has_housing_loan has_personal_loan  prev_call_duration  \
# client_id
# 41020                  yes                no                 283
# 23720                   no               yes                 169
# 29378                   no                no                 552
# 36636                  yes               yes                 206
# 38229                   no                no                 341
#
#            days_since_last_call  num_contacts_prev     poutcome contact_date  \
# client_id
# 41020                         3                  1      success   2018-07-09
# 23720                         6                  2      success   2018-05-07
# 29378                       999                  0  nonexistent   2018-01-08
# 36636                       999                  0  nonexistent   2018-02-11
# 38229                       999                  0  nonexistent   2018-04-04
#
#               cpi  subs_deposit
# client_id
# 41020      92.379             1
# 23720      94.215             1
# 29378      93.444             1
# 36636      93.200             0
# 38229      93.075             1

# %%
def data_factory(df_in):
    df_out = df_in.copy()
    # set client_id as the index
    # df_out.set_index('client_id', inplace=True)
    # normalize the prev_call duration.
    # reset outliters
    df_out.prev_call_duration = df_out.prev_call_duration.apply(lambda x: x/100 if x >120000 else x)
    # set upperbound to 4200
    df_out.prev_call_duration = df_out.prev_call_duration.apply(lambda x: x if x < 4200 else 4200)
    # normalize the days_since_last_call, replace 999 to -1
    df_out.days_since_last_call = df_out.days_since_last_call.apply(lambda x: -1 if x == 999 else x)
    # normalize the cpi
    # reset outliers
    df_out.cpi = df_out.cpi.apply(lambda x: x/10 if x >100 else x)
    # set upperbound to 100
    df_out.cpi = df_out.cpi.apply(lambda x: 100 if x > 100 else x)
    df_out.dropna(inplace=True)

    # replace subs_deposit with Yes to 1 and No to 0
    df_out.subs_deposit = df_out.subs_deposit.apply(lambda x: 'yes' if x == 1 else 'no')
    return df_out

df_train = data_factory(df_raw_train)

# %%
sample_type_test = {
    'client_id': 'str',
 'age_bracket': 'str',
 'job': 'str',
 'marital': 'str',
 'education': 'str',
 'has_housing_loan': 'str',
 'has_personal_loan': 'str',
 'prev_call_duration': 'int',  
 'days_since_last_call': 'int',  
 'num_contacts_prev':'int', 
 'poutcome': 'str',
 'contact_date': 'str',
 'cpi': 'float',
}

data_filepath_test = '../data/raw/test.csv'

df_raw_test = pd.read_csv(
    data_filepath,
    index_col=['client_id'],
    parse_dates=['contact_date'],
    dtype=sample_type,
)
display(df_raw_test.head())
# Out:
#           age_bracket           job   marital         education  \
# client_id
# 41020           41-60  white-collar  divorced         bachelors
# 23720             60+         other  divorced         secondary
# 29378           41-60  white-collar   married         bachelors
# 36636           25-40    technician    single  senior_secondary
# 38229           18-24  white-collar    single         bachelors
#
#           has_housing_loan has_personal_loan  prev_call_duration  \
# client_id
# 41020                  yes                no                 283
# 23720                   no               yes                 169
# 29378                   no                no                 552
# 36636                  yes               yes                 206
# 38229                   no                no                 341
#
#            days_since_last_call  num_contacts_prev     poutcome contact_date  \
# client_id
# 41020                         3                  1      success   2018-07-09
# 23720                         6                  2      success   2018-05-07
# 29378                       999                  0  nonexistent   2018-01-08
# 36636                       999                  0  nonexistent   2018-02-11
# 38229                       999                  0  nonexistent   2018-04-04
#
#               cpi  subs_deposit
# client_id
# 41020      92.379             1
# 23720      94.215             1
# 29378      93.444             1
# 36636      93.200             0
# 38229      93.075             1

# %%
df_test = data_factory(df_raw_test)
display(df_test)
# Out:
#           age_bracket           job   marital         education  \
# client_id
# 41020           41-60  white-collar  divorced         bachelors
# 23720             60+         other  divorced         secondary
# 29378           41-60  white-collar   married         bachelors
# 36636           25-40    technician    single  senior_secondary
# 38229           18-24  white-collar    single         bachelors
# ...               ...           ...       ...               ...
# 7519            41-60  entrepreneur    single         secondary
# 29822           41-60  white-collar   married         bachelors
# 24462           25-40  white-collar   married  senior_secondary
# 26089           25-40   pink-collar   married         secondary
# 40631           25-40  white-collar    single         bachelors
#
#           has_housing_loan has_personal_loan  prev_call_duration  \
# client_id
# 41020                  yes                no               283.0
# 23720                   no               yes               169.0
# 29378                   no                no               552.0
# 36636                  yes               yes               206.0
# 38229                   no                no               341.0
# ...                    ...               ...                 ...
# 7519                   yes                no               396.0
# 29822                  yes                no               115.0
# 24462                  yes                no               214.0
# 26089                  yes                no                76.0
# 40631                  yes                no               368.0
#
#            days_since_last_call  num_contacts_prev     poutcome contact_date  \
# client_id
# 41020                         3                  1      success   2018-07-09
# 23720                         6                  2      success   2018-05-07
# 29378                        -1                  0  nonexistent   2018-01-08
# 36636                        -1                  0  nonexistent   2018-02-11
# 38229                        -1                  0  nonexistent   2018-04-04
# ...                         ...                ...          ...          ...
# 7519                         -1                  0  nonexistent   2018-02-05
# 29822                        -1                  0  nonexistent   2018-01-08
# 24462                        -1                  0  nonexistent   2018-06-07
# 26089                        -1                  0  nonexistent   2018-02-07
# 40631                        -1                  0  nonexistent   2018-04-09
#
#               cpi subs_deposit
# client_id
# 41020      92.379          yes
# 23720      94.215          yes
# 29378      93.444          yes
# 36636      93.200           no
# 38229      93.075          yes
# ...           ...          ...
# 7519       92.893          yes
# 29822      93.444           no
# 24462      93.918           no
# 26089      93.918           no
# 40631      92.379           no
#
# [4000 rows x 13 columns]

# %% [markdown]
# ## 03 Model Development

# %%
from autogluon.tabular import TabularPredictor

label = 'subs_deposit'
save_path = '../models/agModels-CleanRawAcc'  # specifies folder to store trained models

# here we used all the feature.
predictor = TabularPredictor(label=label, path=save_path, eval_metric='balanced_accuracy').fit(df_train)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/agModels-CleanRawAcc"
# Beginning AutoGluon training ...
# AutoGluon will save models to "../models/agModels-CleanRawAcc/"
# AutoGluon Version:  0.4.0
# Python Version:     3.8.10
# Operating System:   Darwin
# Train Data Rows:    4000
# Train Data Columns: 12
# Label Column: subs_deposit
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['yes', 'no']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = yes, class 0 = no
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (yes) vs negative (no) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    33606.32 MB
# 	Train Data (Original)  Memory Usage: 1.95 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) : 1 | ['contact_date']
# 		('float', [])    : 2 | ['prev_call_duration', 'cpi']
# 		('int', [])      : 2 | ['days_since_last_call', 'num_contacts_prev']
# 		('object', [])   : 7 | ['age_bracket', 'job', 'marital', 'education', 'has_housing_loan', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 7 | ['age_bracket', 'job', 'marital', 'education', 'has_housing_loan', ...]
# 		('float', [])                : 2 | ['prev_call_duration', 'cpi']
# 		('int', [])                  : 2 | ['days_since_last_call', 'num_contacts_prev']
# 		('int', ['datetime_as_int']) : 4 | ['contact_date', 'contact_date.month', 'contact_date.day', 'contact_date.dayofweek']
# 	0.1s = Fit runtime
# 	12 features in original data used to generate 15 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.29 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'balanced_accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.7864	 = Validation score   (balanced_accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.7681	 = Validation score   (balanced_accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.8448	 = Validation score   (balanced_accuracy)
# 	1.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.8524	 = Validation score   (balanced_accuracy)
# 	0.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.839	 = Validation score   (balanced_accuracy)
# 	0.46s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.8424	 = Validation score   (balanced_accuracy)
# 	0.5s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.8607	 = Validation score   (balanced_accuracy)
# 	3.67s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7997	 = Validation score   (balanced_accuracy)
# 	0.44s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.803	 = Validation score   (balanced_accuracy)
# 	0.45s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	0.8424	 = Validation score   (balanced_accuracy)
# 	3.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.8633	 = Validation score   (balanced_accuracy)
# 	0.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.8341	 = Validation score   (balanced_accuracy)
# 	5.91s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.8515	 = Validation score   (balanced_accuracy)
# 	1.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.8791	 = Validation score   (balanced_accuracy)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 20.56s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/agModels-CleanRawAcc/")

# %%
save_report_leaderboard_csv = '../reports/df_clean_raw_acc_leaderboard.csv'
df_report = predictor.leaderboard(df_train, silent=True, extra_metrics=[predictor.eval_metric])
df_report.to_csv(save_report_leaderboard_csv )
display(df_report)
# Out:
#                   model  score_test  balanced_accuracy  score_val  \
# 0      RandomForestEntr    0.980293           0.980293   0.842376
# 1      RandomForestGini    0.979872           0.979872   0.839012
# 2        ExtraTreesEntr    0.975369           0.975369   0.803027
# 3        ExtraTreesGini    0.974947           0.974947   0.799663
# 4        KNeighborsDist    0.969339           0.969339   0.768060
# 5   WeightedEnsemble_L2    0.961864           0.961864   0.879130
# 6               XGBoost    0.932587           0.932587   0.863287
# 7         LightGBMLarge    0.924265           0.924265   0.851533
# 8              CatBoost    0.921526           0.921526   0.860732
# 9            LightGBMXT    0.909729           0.909729   0.844847
# 10      NeuralNetFastAI    0.884294           0.884294   0.842418
# 11             LightGBM    0.882724           0.882724   0.852385
# 12       NeuralNetTorch    0.854624           0.854624   0.834071
# 13       KNeighborsUnif    0.829878           0.829878   0.786415
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.123698       0.047108   0.503647                 0.123698
# 1         0.102994       0.044437   0.460479                 0.102994
# 2         0.146977       0.045240   0.454100                 0.146977
# 3         0.157998       0.046098   0.437306                 0.157998
# 4         0.048678       0.008131   0.007480                 0.048678
# 5         0.395431       0.097837  11.537287                 0.003996
# 6         0.026145       0.006806   0.545246                 0.026145
# 7         0.013458       0.006187   1.101521                 0.013458
# 8         0.016372       0.007974   3.671559                 0.016372
# 9         0.029335       0.007528   1.422638                 0.029335
# 10        0.099449       0.013950   3.842991                 0.099449
# 11        0.010070       0.005983   0.458005                 0.010070
# 12        0.228953       0.025005   5.912788                 0.228953
# 13        0.015208       0.006845   0.005973                 0.015208
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.047108           0.503647            1       True
# 1                 0.044437           0.460479            1       True
# 2                 0.045240           0.454100            1       True
# 3                 0.046098           0.437306            1       True
# 4                 0.008131           0.007480            1       True
# 5                 0.001163           0.508546            2       True
# 6                 0.006806           0.545246            1       True
# 7                 0.006187           1.101521            1       True
# 8                 0.007974           3.671559            1       True
# 9                 0.007528           1.422638            1       True
# 10                0.013950           3.842991            1       True
# 11                0.005983           0.458005            1       True
# 12                0.025005           5.912788            1       True
# 13                0.006845           0.005973            1       True
#
#     fit_order
# 0           6
# 1           5
# 2           9
# 3           8
# 4           2
# 5          14
# 6          11
# 7          13
# 8           7
# 9           3
# 10         10
# 11          4
# 12         12
# 13          1

# %%
best_model_name = df_report[df_report.balanced_accuracy == df_report.balanced_accuracy.max()].model[0]
predictor.set_model_best(best_model_name)
predictor.save()
print('Best model is saved as {}'.format(best_model_name))
# Out:
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/agModels-CleanRawAcc/")
# Best model is saved as RandomForestEntr

# %% [markdown]
# ### Training Performacne

# %%
data = df_train.drop(columns='subs_deposit')
target = df_train.subs_deposit 

y_pred = predictor.predict(data)
# print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=target,
                                         y_pred=y_pred,
                                         auxiliary_metrics=True)
# Out:
# Evaluation: balanced_accuracy on test data: 0.9802930661029776
# Evaluations on test data:
# {
#     "balanced_accuracy": 0.9802930661029776,
#     "accuracy": 0.98025,
#     "mcc": 0.9588796642456014,
#     "f1": 0.975289333750391,
#     "precision": 0.970130678282514,
#     "recall": 0.980503144654088
# }

# %% [markdown]
# ## Test Prediction

# %%
y_pred_test = predictor.predict(df_test)

# %% [markdown]
# Create a submission file for the test data.

# %%
df_submission = y_pred_test.to_frame('subs_deposit')
df_submission.subs_deposit = df_submission.subs_deposit.apply(lambda x: 1 if x == 'yes' else 0)
df_submission.to_csv('../reports/submission_acc.csv')

# %%
df_submission.head()
# Out:
#            subs_deposit
# client_id
# 41020                 1
# 23720                 1
# 29378                 1
# 36636                 0
# 38229                 1

# %% [markdown]
# ## 04 Try Model with F1 evaluation metric

# %%
save_path = '../models/agModels-CleanRawF1'  # specifies folder to store trained models

# here we used all the feature.
predictor = TabularPredictor(label=label, path=save_path, eval_metric='f1').fit(df_train, hyperparameters={'GBM':{}, 'XGB':{},'XT':{}, 'RF':{}, 'LR':{},'KNN':{},'FASTAI':{}})
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/agModels-CleanRawF1"
# Beginning AutoGluon training ...
# AutoGluon will save models to "../models/agModels-CleanRawF1/"
# AutoGluon Version:  0.4.0
# Python Version:     3.8.10
# Operating System:   Darwin
# Train Data Rows:    4000
# Train Data Columns: 12
# Label Column: subs_deposit
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['yes', 'no']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = yes, class 0 = no
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (yes) vs negative (no) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    33372.05 MB
# 	Train Data (Original)  Memory Usage: 1.95 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) : 1 | ['contact_date']
# 		('float', [])    : 2 | ['prev_call_duration', 'cpi']
# 		('int', [])      : 2 | ['days_since_last_call', 'num_contacts_prev']
# 		('object', [])   : 7 | ['age_bracket', 'job', 'marital', 'education', 'has_housing_loan', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 7 | ['age_bracket', 'job', 'marital', 'education', 'has_housing_loan', ...]
# 		('float', [])                : 2 | ['prev_call_duration', 'cpi']
# 		('int', [])                  : 2 | ['days_since_last_call', 'num_contacts_prev']
# 		('int', ['datetime_as_int']) : 4 | ['contact_date', 'contact_date.month', 'contact_date.day', 'contact_date.dayofweek']
# 	0.1s = Fit runtime
# 	12 features in original data used to generate 15 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.29 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.21s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 7 L1 models ...
# Fitting model: KNeighbors ...
# 	0.7445	 = Validation score   (f1)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.8213	 = Validation score   (f1)
# 	1.14s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest ...
# 	0.8058	 = Validation score   (f1)
# 	0.44s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees ...
# 	0.7588	 = Validation score   (f1)
# 	0.5s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.8095	 = Validation score   (f1)
# 	3.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.8333	 = Validation score   (f1)
# 	0.89s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LinearModel ...
# 	0.7626	 = Validation score   (f1)
# 	2.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.8333	 = Validation score   (f1)
# 	0.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 10.26s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/agModels-CleanRawF1/")

# %%
save_report_leaderboard_csv = '../reports/df_clean_raw_f1_leaderboard.csv'
df_report = predictor.leaderboard(df_train, silent=True, extra_metrics=[predictor.eval_metric])
df_report.to_csv(save_report_leaderboard_csv )
display(df_report)
# Out:
#                  model  score_test        f1  score_val  pred_time_test  \
# 0         RandomForest    0.974953  0.974953   0.805825        0.087640
# 1           ExtraTrees    0.969811  0.969811   0.758794        0.117578
# 2              XGBoost    0.915140  0.915140   0.833333        0.041911
# 3  WeightedEnsemble_L2    0.915140  0.915140   0.833333        0.043708
# 4      NeuralNetFastAI    0.858094  0.858094   0.809524        0.067836
# 5             LightGBM    0.857852  0.857852   0.821256        0.010096
# 6           KNeighbors    0.795003  0.795003   0.744526        0.029963
# 7          LinearModel    0.774693  0.774693   0.762626        0.013357
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.048268  0.442106                 0.087640                0.048268
# 1       0.045478  0.500015                 0.117578                0.045478
# 2       0.007735  0.885735                 0.041911                0.007735
# 3       0.009382  1.539423                 0.001797                0.001647
# 4       0.014951  3.805497                 0.067836                0.014951
# 5       0.006438  1.135036                 0.010096                0.006438
# 6       0.006463  0.006851                 0.029963                0.006463
# 7       0.013102  2.025372                 0.013357                0.013102
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.442106            1       True          3
# 1           0.500015            1       True          4
# 2           0.885735            1       True          6
# 3           0.653688            2       True          8
# 4           3.805497            1       True          5
# 5           1.135036            1       True          2
# 6           0.006851            1       True          1
# 7           2.025372            1       True          7

# %%
best_model_name = df_report[df_report.f1 == df_report.f1.max()].model[0]
predictor.set_model_best(best_model_name)
predictor.save()
print('Best model is saved as {}'.format(best_model_name))
# Out:
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/agModels-CleanRawF1/")
# Best model is saved as RandomForest

# %%
# Training performance
data = df_train.drop(columns='subs_deposit')
target = df_train.subs_deposit 

y_pred = predictor.predict(data)
# print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=target,
                                         y_pred=y_pred,
                                         auxiliary_metrics=True)
# Out:
# Evaluation: f1 on test data: 0.9749530369442705
# Evaluations on test data:
# {
#     "f1": 0.9749530369442705,
#     "accuracy": 0.98,
#     "balanced_accuracy": 0.9798716041650356,
#     "mcc": 0.9583332181532717,
#     "precision": 0.9706982543640897,
#     "recall": 0.9792452830188679
# }

# %%
y_pred_test = predictor.predict(df_test)
df_submission = y_pred_test.to_frame('subs_deposit')
df_submission.subs_deposit = df_submission.subs_deposit.apply(lambda x: 1 if x == 'yes' else 0)
df_submission.to_csv('../reports/submission_f1.csv')

# %%
df_submission.head()
# Out:
#            subs_deposit
# client_id
# 41020                 1
# 23720                 1
# 29378                 1
# 36636                 0
# 38229                 1

# %% [markdown]
# ## 05 Feature Importances.

# %%
df_fi= predictor.feature_importance(df_train)
df_fi
# Out:
# Computing feature importance via permutation shuffling for 12 features using 1000 rows with 3 shuffle sets...
# 	2.98s	= Expected runtime (0.99s per shuffle set)
# 	0.81s	= Actual runtime (Completed 3 of 3 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# prev_call_duration      0.363587  0.019175  0.000463  3  0.473464  0.253710
# contact_date            0.151400  0.001646  0.000020  3  0.160832  0.141968
# cpi                     0.114571  0.005748  0.000419  3  0.147510  0.081633
# job                     0.030849  0.003014  0.001583  3  0.048119  0.013580
# marital                 0.024129  0.008665  0.020199  3  0.073778 -0.025521
# education               0.023910  0.009940  0.026535  3  0.080870 -0.033050
# age_bracket             0.017644  0.001202  0.000771  3  0.024530  0.010759
# has_housing_loan        0.012618  0.004196  0.017468  3  0.036659 -0.011424
# days_since_last_call    0.011674  0.003862  0.017302  3  0.033805 -0.010457
# num_contacts_prev       0.009759  0.002117  0.007664  3  0.021891 -0.002373
# has_personal_loan       0.008155  0.003646  0.030316  3  0.029045 -0.012736
# poutcome                0.002392  0.000038  0.000041  3  0.002607  0.002176

# %%
# df_fi.importance.sum()
df_fi.to_csv('../reports/feature_importance.csv')

# %% [markdown]
# ## 06 Web Service REST API

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
model = TabularPredictor.load(save_path)

# %%
model.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                  model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0              XGBoost   0.833333       0.007735  0.885735                0.007735           0.885735            1       True          6
# 1  WeightedEnsemble_L2   0.833333       0.009382  1.539423                0.001647           0.653688            2       True          8
# 2             LightGBM   0.821256       0.006438  1.135036                0.006438           1.135036            1       True          2
# 3      NeuralNetFastAI   0.809524       0.014951  3.805497                0.014951           3.805497            1       True          5
# 4         RandomForest   0.805825       0.048268  0.442106                0.048268           0.442106            1       True          3
# 5          LinearModel   0.762626       0.013102  2.025372                0.013102           2.025372            1       True          7
# 6           ExtraTrees   0.758794       0.045478  0.500015                0.045478           0.500015            1       True          4
# 7           KNeighbors   0.744526       0.006463  0.006851                0.006463           0.006851            1       True          1
# Number of models trained: 8
# Types of models trained:
# {'XTModel', 'WeightedEnsembleModel', 'XGBoostModel', 'LinearModel', 'KNNModel', 'RFModel', 'LGBModel', 'NNFastAiTabularModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             : 7 | ['age_bracket', 'job', 'marital', 'education', 'has_housing_loan', ...]
# ('float', [])                : 2 | ['prev_call_duration', 'cpi']
# ('int', [])                  : 2 | ['days_since_last_call', 'num_contacts_prev']
# ('int', ['datetime_as_int']) : 4 | ['contact_date', 'contact_date.month', 'contact_date.day', 'contact_date.dayofweek']
# *** End of fit() summary ***
# /Users/caihaocui/opt/miniconda3/envs/lending_bank_client_ranking/lib/python3.8/site-packages/autogluon/core/utils/plots.py:138: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighbors': 'KNNModel',
#   'LightGBM': 'LGBModel',
#   'RandomForest': 'RFModel',
#   'ExtraTrees': 'XTModel',
#   'NeuralNetFastAI': 'NNFastAiTabularModel',
#   'XGBoost': 'XGBoostModel',
#   'LinearModel': 'LinearModel',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighbors': 0.7445255474452555,
#   'LightGBM': 0.8212560386473431,
#   'RandomForest': 0.8058252427184466,
#   'ExtraTrees': 0.7587939698492462,
#   'NeuralNetFastAI': 0.8095238095238095,
#   'XGBoost': 0.8333333333333334,
#   'LinearModel': 0.7626262626262627,
#   'WeightedEnsemble_L2': 0.8333333333333334},
#  'model_best': 'RandomForest',
#  'model_paths': {'KNeighbors': '../models/agModels-CleanRawF1/models/KNeighbors/',
#   'LightGBM': '../models/agModels-CleanRawF1/models/LightGBM/',
#   'RandomForest': '../models/agModels-CleanRawF1/models/RandomForest/',
#   'ExtraTrees': '../models/agModels-CleanRawF1/models/ExtraTrees/',
#   'NeuralNetFastAI': '../models/agModels-CleanRawF1/models/NeuralNetFastAI/',
#   'XGBoost': '../models/agModels-CleanRawF1/models/XGBoost/',
#   'LinearModel': '../models/agModels-CleanRawF1/models/LinearModel/',
#   'WeightedEnsemble_L2': '../models/agModels-CleanRawF1/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighbors': 0.0068509578704833984,
#   'LightGBM': 1.135035753250122,
#   'RandomForest': 0.442105770111084,
#   'ExtraTrees': 0.5000147819519043,
#   'NeuralNetFastAI': 3.80549693107605,
#   'XGBoost': 0.885735034942627,
#   'LinearModel': 2.025371789932251,
#   'WeightedEnsemble_L2': 0.6536877155303955},
#  'model_pred_times': {'KNeighbors': 0.006463050842285156,
#   'LightGBM': 0.006438255310058594,
#   'RandomForest': 0.04826807975769043,
#   'ExtraTrees': 0.045478105545043945,
#   'NeuralNetFastAI': 0.014950990676879883,
#   'XGBoost': 0.007735013961791992,
#   'LinearModel': 0.013102054595947266,
#   'WeightedEnsemble_L2': 0.0016469955444335938},
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighbors': {'weights': 'uniform'},
#   'LightGBM': {'learning_rate': 0.05},
#   'RandomForest': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True},
#   'ExtraTrees': {'n_estimators': 300,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True},
#   'NeuralNetFastAI': {'layers': None,
#    'emb_drop': 0.1,
#    'ps': 0.1,
#    'bs': 'auto',
#    'lr': 0.01,
#    'epochs': 'auto',
#    'early.stopping.min_delta': 0.0001,
#    'early.stopping.patience': 20,
#    'smoothing': 0.0},
#   'XGBoost': {'n_estimators': 10000,
#    'learning_rate': 0.1,
#    'n_jobs': -1,
#    'proc.max_category_levels': 100,
#    'objective': 'binary:logistic',
#    'booster': 'gbtree',
#    'use_label_encoder': False},
#   'LinearModel': {'random_state': 0,
#    'fit_intercept': True,
#    'solver': 'lbfgs',
#    'C': 1,
#    'vectorizer_dict_size': 75000,
#    'proc.ngram_range': (1, 5),
#    'proc.skew_threshold': 0.99,
#    'proc.impute_strategy': 'median',
#    'penalty': 'L2',
#    'handle_text': 'ignore'},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                  model  score_val  pred_time_val  fit_time  \
#  0              XGBoost   0.833333       0.007735  0.885735
#  1  WeightedEnsemble_L2   0.833333       0.009382  1.539423
#  2             LightGBM   0.821256       0.006438  1.135036
#  3      NeuralNetFastAI   0.809524       0.014951  3.805497
#  4         RandomForest   0.805825       0.048268  0.442106
#  5          LinearModel   0.762626       0.013102  2.025372
#  6           ExtraTrees   0.758794       0.045478  0.500015
#  7           KNeighbors   0.744526       0.006463  0.006851
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                0.007735           0.885735            1       True
#  1                0.001647           0.653688            2       True
#  2                0.006438           1.135036            1       True
#  3                0.014951           3.805497            1       True
#  4                0.048268           0.442106            1       True
#  5                0.013102           2.025372            1       True
#  6                0.045478           0.500015            1       True
#  7                0.006463           0.006851            1       True
#
#     fit_order
#  0          6
#  1          8
#  2          2
#  3          5
#  4          3
#  5          7
#  6          4
#  7          1  }

# %%
sample = {'client_id': '123456', 'age_bracket': '18-24', 'job': 'white-collar', 'marital': 'married', 'education': 'bachelors', 'has_housing_loan': 'yes', 'has_personal_loan': 'yes', 'prev_call_duration': '237', 'days_since_last_call': '3', 'num_contacts_prev': '1', 'poutcome': 'success', 'contact_date': '2018-02-05', 'cpi': '92.81'}
print(sample)
# Out:
# {'client_id': '123456', 'age_bracket': '18-24', 'job': 'white-collar', 'marital': 'married', 'education': 'bachelors', 'has_housing_loan': 'yes', 'has_personal_loan': 'yes', 'prev_call_duration': '237', 'days_since_last_call': '3', 'num_contacts_prev': '1', 'poutcome': 'success', 'contact_date': '2018-02-05', 'cpi': '92.81'}

# %%
df_xin = pd.DataFrame([sample])
df_xin.set_index('client_id', inplace=True)
df_xin
# Out:
#           age_bracket           job  marital  education has_housing_loan  \
# client_id
# 123456          18-24  white-collar  married  bachelors              yes
#
#           has_personal_loan prev_call_duration days_since_last_call  \
# client_id
# 123456                  yes                237                    3
#
#           num_contacts_prev poutcome contact_date    cpi
# client_id
# 123456                    1  success   2018-02-05  92.81

# %%
y_pred = model.predict(df_xin)
y_proba = model.predict_proba(df_xin)
print(y_pred, y_proba)
# Out:
# client_id
# 123456    yes
# Name: subs_deposit, dtype: object                  no       yes
# client_id
# 123456     0.176667  0.823333

# %% [markdown]
# ## END  OF NOTEBOOK
